# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID           City Country  Max Temp Current Description      Lat  \
# 0        0       Souillac      MU     78.80          light rain -20.5167
# 1        8        Rikitea      PF     78.24    scattered clouds -23.1203
# 2       13         Touros      BR     78.80    scattered clouds  -5.1989
# 3       21  Clarence Town      AU     84.99          few clouds -32.5833
# 4       22       Cidreira      BR     76.50          few clouds -30.1811
#
#         Lng                   Hotel Name
# 0   57.5167  Shanti Maurice Resort & Spa
# 1 -134.9692               Pension Maro'i
# 2  -35.4608              INN NEW HORIZON
# 3  151.7833          River Downs Cottage
# 4  -50.2056                Hotel Castelo

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name </dt><dd>{Hotel Name}</dd>
<dt>City </dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Trip into Brazil.
# Grab the first hotel from the results and store the name.
brazil_vacation_df = vacation_df.loc[(vacation_df["Country"] == "BR")]
brazil_vacation_df.dropna()
# Out:
#      City_ID                      City Country  Max Temp Current Description  \
# 2         13                    Touros      BR     78.80    scattered clouds
# 4         22                  Cidreira      BR     76.50          few clouds
# 26       110               Salinopolis      BR     79.07          light rain
# 33       137                   Aquiraz      BR     78.80           clear sky
# 51       194           Arraial Do Cabo      BR     76.37    scattered clouds
# 63       234         Sao Joao Da Barra      BR     76.55    scattered clouds
# 68       248                  Ilhabela      BR     77.29     overcast clouds
# 72       260                   Caucaia      BR     80.01           clear sky
# 77       275                Vila Velha      BR     77.00          light rain
# 78       279                Rio Grande      BR     75.99    scattered clouds
# 85       302                  Maragogi      BR     76.30     overcast clouds
# ...

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.
#Pitimbu ,#Olinda,# Sao Jose Da Coroa Grande,#Maragogi
vacation_start = brazil_vacation_df.loc[131] 
vacation_end = brazil_vacation_df.loc[131]
vacation_stop1 = brazil_vacation_df.loc[94] 
vacation_stop2 = brazil_vacation_df.loc[133]  
vacation_stop3 = brazil_vacation_df.loc[85]
# Out:
# City_ID                             516
# City                            Pitimbu
# Country                              BR
# Max Temp                           78.8
# Current Description       broken clouds
# Lat                             -7.4706
# Lng                            -34.8086
# Hotel Name             Reserva do Abiaí
# Name: 131, dtype: object

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
#start = pd.DataFrame(vacation_start[["Lat", "Lng"]]).to_numpy()
#end = pd.DataFrame(vacation_end[["Lat", "Lng"]]).to_numpy()
#stop1 = pd.DataFrame(vacation_stop1[["Lat", "Lng"]]).to_numpy()
#stop2 = pd.DataFrame(vacation_stop2[["Lat", "Lng"]]).to_numpy()
#stop3 = pd.DataFrame(vacation_stop3[["Lat", "Lng"]]).to_numpy()

start = vacation_start[["Lat", "Lng"]]
end = vacation_end[["Lat", "Lng"]]
stop1 = vacation_stop1[["Lat", "Lng"]]
stop2 = vacation_stop2[["Lat", "Lng"]]
stop3 = vacation_stop3[["Lat", "Lng"]]


print(start)
print(end)
print(stop1)
print(stop2)
print(stop3)
# Out:
# Lat    -7.4706
# Lng   -34.8086
# Name: 131, dtype: object
# Lat    -7.4706
# Lng   -34.8086
# Name: 131, dtype: object
# Lat    -8.0089
# Lng   -34.8553
# Name: 94, dtype: object
# Lat    -8.8978
# Lng   -35.1478
# Name: 133, dtype: object
# Lat    -9.0122
# Lng   -35.2225
# Name: 85, dtype: object

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)
ﬁ
fig = gmaps.figure()
sart2end_via_stops = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3],travel_mode='DRIVING')
fig.add_layer(sart2end_via_stops)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([brazil_vacation_df],ignore_index=True)
itinerary_df
# Out:
#     City_ID                      City Country  Max Temp Current Description  \
# 0        13                    Touros      BR     78.80    scattered clouds
# 1        22                  Cidreira      BR     76.50          few clouds
# 2       110               Salinopolis      BR     79.07          light rain
# 3       137                   Aquiraz      BR     78.80           clear sky
# 4       194           Arraial Do Cabo      BR     76.37    scattered clouds
# 5       234         Sao Joao Da Barra      BR     76.55    scattered clouds
# 6       248                  Ilhabela      BR     77.29     overcast clouds
# 7       260                   Caucaia      BR     80.01           clear sky
# 8       275                Vila Velha      BR     77.00          light rain
# 9       279                Rio Grande      BR     75.99    scattered clouds
# 10      302                  Maragogi      BR     76.30     overcast clouds
# ...

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name </dt><dd>{Hotel Name}</dd>
<dt>City </dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
city_mark = itinerary_df["City"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
